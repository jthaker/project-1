# %%
#import depedencies
import pandas as pd

# %%
#insert csv
tuition_data = "raw_data/cp-2018-Table-2.csv"
wages_data = "raw_data/wage_data.csv"
loan_data = "raw_data/2018-trends-student-aid-source-data_0.csv"

# %%
#create dataframe from excel data
schooldf = pd.read_csv(tuition_data)
schooldf.head()
# Out:
#   TABLE 2. Average Tuition and Fees and Room and Board (Enrollment-Weighted) in Current Dollars and in 2018 Dollars, 1971-72 to 2018-19  \
# 0                                                NaN
# 1                                      Academic Year
# 2                                              71-72
# 3                                              72-73
# 4                                              73-74
#
#                          Unnamed: 1         Unnamed: 2        Unnamed: 3  \
# 0  Tuition and Fees in 2018 Dollars                NaN               NaN
# 1       Private Nonprofit Four-Year  One-Year % Change  Public Four-Year
# 2                           $11,330                  —            $2,660
# 3                           $11,730               3.5%            $3,010
# 4                           $11,660              -0.6%            $2,900
#
#           Unnamed: 4       Unnamed: 5         Unnamed: 6  \
# 0                NaN              NaN                NaN
# ...
